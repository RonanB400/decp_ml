# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_PATH = os.path.join(os.path.dirname(os.getcwd()),
                        'data')
MODEL_PATH = os.path.join(os.path.dirname(os.getcwd()),
                            'models', 'estimation')
os.makedirs(MODEL_PATH, exist_ok=True)

df = pd.read_csv(os.path.join(DATA_PATH,'data_clean.csv'))

# %%
df.to_csv(os.path.join(DATA_PATH,"data_clean_bigquery.csv"), index=False, quoting=1)

# %%
from google.cloud import bigquery

GCP_PROJECT = os.environ.get("GCP_PROJECT")
BQ_DATASET = os.environ.get("BQ_DATASET")
BQ_TABLE = os.environ.get("BQ_TABLE")


query = f"""
    SELECT *
    FROM {GCP_PROJECT}.{BQ_DATASET}.{BQ_TABLE}
    LIMIT 100
    """


client = bigquery.Client(project=GCP_PROJECT)
query_job = client.query(query)
result = query_job.result()
df = result.to_dataframe()

df.head()
# Out:
# /home/ronan/.pyenv/versions/3.10.6/envs/decp_ml_env/lib/python3.10/site-packages/google/cloud/bigquery/table.py:1957: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                             uid              id  nature     acheteur_id  \
# 0          20005383300014202107          202107  Marché  20005383300014
# 1  2000605150001820210000000003  20210000000003  Marché  20006051500018
# 2  2000605150001820210000000003  20210000000003  Marché  20006051500018
# 3        2000605150001820220901        20220901  Marché  20006051500018
# 4        2000605150001820220902        20220902  Marché  20006051500018
#
#                      acheteur_nom  acheteur_siren    titulaire_id  \
# 0            COMMUNE DE ENTRELACS     200053833.0  52974481500026
# 1  COMMUNE DE LIVAROT-PAYS-D'AUGE     200060515.0  34750812900033
# 2  COMMUNE DE LIVAROT-PAYS-D'AUGE     200060515.0  34188212400041
# 3  COMMUNE DE LIVAROT-PAYS-D'AUGE     200060515.0  32181488100017
# 4  COMMUNE DE LIVAROT-PAYS-D'AUGE     200060515.0  32181488100017
#
#   titulaire_typeIdentifiant       titulaire_nom  titulaire_siren  ...  \
# 0                     SIRET          DYN'A.M.O.      529744815.0  ...
# 1                     SIRET   FEUILLE A FEUILLE      347508129.0  ...
# 2                     SIRET  BET SAISON-PARAGOT      341882124.0  ...
# 3                     SIRET          TOFFOLUTTI      321814881.0  ...
# 4                     SIRET          TOFFOLUTTI      321814881.0  ...
#
#   codeCPV_2  codeCPV_3 codeCPV_4 codeCPV_5  codeCPV_2_3 annee  \
# 0         0          0         0         0            0  2021
# 1         0          0         0         0            0  2020
# 2         0          0         0         0            0  2020
# 3         0          0         0         0            0  2022
# 4         0          0         0         0            0  2022
#
#   acheteur_tranche_effectif acheteur_categorie  titulaire_tranche_effectif  \
# 0                        22                PME
# 1                        22                PME                          02
# 2                        22                PME                          02
# 3                        22                PME                          31
# 4                        22                PME                          31
#
#    titulaire_categorie
# 0                  PME
# 1                  PME
# 2                  PME
# 3                  ETI
# 4                  ETI
#
# [5 rows x 42 columns]
