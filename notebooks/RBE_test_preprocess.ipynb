# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import sqlite3

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from scripts.data_cleaner import filter_top_cpv_categories
from scripts.preprocess_pipeline import create_pipeline_cat

# %%
data_path = os.path.join(os.path.dirname(os.getcwd()), 'data')
df = pd.read_csv(os.path.join(os.path.dirname(os.getcwd()), 'data', 'data_clean.csv'))

# %%
df = filter_top_cpv_categories(df, top_n=40, cpv_column='codeCPV_2')
df.head()
# Out:
# Filtered from 73 to 40 CPV categories, keeping 283975 rows out of 286850
#                             uid              id  nature     acheteur_id  \
# 0       210601209000132022_M013       2022_M013  Marché  21060120900013
# 1   217100759000182024RENOCHARP   2024RENOCHARP  Marché  21710075900018
# 2  200066231000162022033INFOL00  2022033INFOL00  Marché  20006623100016
# 3         243100518001702024M05         2024M05  Marché  24310051800170
# 4       21590544900017202402401       202402401  Marché  21590544900017
#
#                         acheteur_nom  acheteur_siren    titulaire_id  \
# 0  COMMUNE DE SAINT ETIENNE DE TINEE     210601209.0  38177692100029
# 1                COMMUNE DE CHALMOUX     217100759.0  75203574100038
# 2    CC DES PORTES D'ARIEGE PYRENEES     200066231.0  49459697600014
# 3                 TOULOUSE METROPOLE     243100518.0  59278023300017
# 4            COMMUNE DE SAINT SAULVE     215905449.0  32683156700010
#
#   titulaire_typeIdentifiant              titulaire_nom  titulaire_siren  ...  \
# 0                     SIRET                  SERMATECH      381776921.0  ...
# 1                     SIRET           MACON ETANCHEITE      752035741.0  ...
# 2                     SIRET                    EQUADEX      494596976.0  ...
# 3                     SIRET  RIVES & EAUX DU SUD-OUEST      592780233.0  ...
# 4                     SIRET            ALTOMARE ALTALU      326831567.0  ...
#
#   lieuExecution_typeCode   idAccordCadre                source_open_data  \
# 0            Code postal             NaN     data.gouv.fr decp-2024.json
# 1            Code postal             NaN  data.gouv.fr decp-2025-01.json
# 2            Code postal  2022033INFOL00     data.gouv.fr decp-2024.json
# 3            Code postal             NaN  data.gouv.fr decp-2025-04.json
# 4            Code postal             NaN     data.gouv.fr decp-2024.json
#
#                                           codeCPV_FR  codeCPV_2 codeCPV_3  \
# 0               Travaux de construction de bâtiments   45000000  45200000
# 1  Travaux de charpente et de couverture et trava...   45000000  45200000
# 2  Services de gestion d'installations pour le dé...   72000000  72500000
# 3                              Services d'ingénierie   71000000  71300000
# 4                                         Serrurerie   44000000  44300000
#
#   codeCPV_4 codeCPV_5  codeCPV_2_3  annee
# 0  45210000  45210000     45200000   2021
# 1  45260000  45261000     45200000   2023
# 2  72510000  72514000     72000000   2023
# 3  71300000  71300000     71300000   2024
# 4  44310000  44316000     44000000   2024
#
# [5 rows x 38 columns]

# %%
cat_list = ['marche_sim', 'pred_montant', 'anomalie']
cat = cat_list[0]

create_pipeline_cat(cat)
# Out:
# Pipeline(steps=[('init',
#                  Pipeline(steps=[('id_accord_encoder', IdAccordCadreEncoder()),
#                                  ('taux_avance_categorizer',
#                                   TauxAvanceCategorizer()),
#                                  ('outliers_feature_rows_selector',
#                                   InitTransformer(binary_columns=['sousTraitanceDeclaree',
#                                                                   'origineFrance',
#                                                                   'marcheInnovant',
#                                                                   'idAccordCadre'],
#                                                   categorical_columns=['procedure',
#                                                                        'nature',
#                                                                        'formePrix',
#                                                                        'ccag',
#                                                                        'typeGroupem...
#                                                                                     SimpleImputer(fill_value='missing',
#                                                                                                   strategy='constant')),
#                                                                                    ('string_converter',
#                                                                                     StringConverter()),
#                                                                                    ('onehot',
#                                                                                     OneHotEncoder(handle_unknown='ignore',
#                                                                                                   sparse_output=False))]),
#                                                                    ['procedure',
#                                                                     'nature',
#                                                                     'formePrix',
#                                                                     'ccag',
#                                                                     'typeGroupementOperateurs',
#                                                                     'tauxAvance_cat',
#                                                                     'codeCPV_2'])]))])),
#                 ('to_dataframe',
#                  FunctionTransformer(func=<function create_pipeline.<locals>.<lambda> at 0x7f5c3a53b5b0>))])
