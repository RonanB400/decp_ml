# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

# %%
data_path = os.path.join(os.path.dirname(os.getcwd()), 'data')
data = pd.read_csv(os.path.join(os.path.dirname(os.getcwd()), 'data', 'data_cpv.csv'))

# %%
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from scripts.row_droppers import drop_outliers, filter_top_cpv_categories

# %%
df_outliers = drop_outliers(data)
df_outliers = filter_top_cpv_categories(df_outliers)
df_outliers.head()
# Out:
# Filtered from 73 to 40 CPV categories, keeping 284618 rows out of 287498
#                             uid              id  nature     acheteur_id  \
# 0       210601209000132022_M013       2022_M013  Marché  21060120900013
# 1   217100759000182024RENOCHARP   2024RENOCHARP  Marché  21710075900018
# 2  200066231000162022033INFOL00  2022033INFOL00  Marché  20006623100016
# 3         243100518001702024M05         2024M05  Marché  24310051800170
# 4       21590544900017202402401       202402401  Marché  21590544900017
#
#                         acheteur_nom  acheteur_siren    titulaire_id  \
# 0  COMMUNE DE SAINT ETIENNE DE TINEE     210601209.0  38177692100029
# 1                COMMUNE DE CHALMOUX     217100759.0  75203574100038
# 2    CC DES PORTES D'ARIEGE PYRENEES     200066231.0  49459697600014
# 3                 TOULOUSE METROPOLE     243100518.0  59278023300017
# 4            COMMUNE DE SAINT SAULVE     215905449.0  32683156700010
#
#   titulaire_typeIdentifiant              titulaire_nom  titulaire_siren  ...  \
# 0                     SIRET                  SERMATECH      381776921.0  ...
# 1                     SIRET           MACON ETANCHEITE      752035741.0  ...
# 2                     SIRET                    EQUADEX      494596976.0  ...
# 3                     SIRET  RIVES & EAUX DU SUD-OUEST      592780233.0  ...
# 4                     SIRET            ALTOMARE ALTALU      326831567.0  ...
#
#   origineFrance  lieuExecution_code lieuExecution_typeCode   idAccordCadre  \
# 0           NaN               06660            Code postal             NaN
# 1           0.0               71140            Code postal             NaN
# 2           NaN               09100            Code postal  2022033INFOL00
# 3           0.0               31000            Code postal             NaN
# 4           NaN               59800            Code postal             NaN
#
#                  source_open_data  \
# 0     data.gouv.fr decp-2024.json
# 1  data.gouv.fr decp-2025-01.json
# 2     data.gouv.fr decp-2024.json
# 3  data.gouv.fr decp-2025-04.json
# 4     data.gouv.fr decp-2024.json
#
#                                           codeCPV_FR codeCPV_2 codeCPV_3  \
# 0               Travaux de construction de bâtiments  45000000  45200000
# 1  Travaux de charpente et de couverture et trava...  45000000  45200000
# 2  Services de gestion d'installations pour le dé...  72000000  72500000
# 3                              Services d'ingénierie  71000000  71300000
# 4                                         Serrurerie  44000000  44300000
#
#    codeCPV_4  codeCPV_5
# 0   45210000   45210000
# 1   45260000   45261000
# 2   72510000   72514000
# 3   71300000   71300000
# 4   44310000   44316000
#
# [5 rows x 36 columns]

# %%
from scripts.column_creators import create_columns

df_columns = create_columns(df_outliers)
df_columns['codeCPV_2'].head()
# Out:
# /home/ronan/code/RonanB400/Project/decp_ml/scripts/column_creators.py:64: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df['annee'] = pd.to_datetime(df['annee'], errors='ignore')
# 0    45200000
# 1    45200000
# 2    72000000
# 3    71300000
# 4    44000000
# Name: codeCPV_2, dtype: int64
