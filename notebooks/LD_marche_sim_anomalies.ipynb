# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import logging

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN



from scripts.preprocess_pipeline import create_pipeline
from scripts.data_cleaner import filter_top_cpv_categories
from scripts.synthetic_anomaly_generator import (SyntheticAnomalyGenerator,
                                                OriginalAnomalyRemover)

# %%
data_path='../data/data_clean.csv'
model_save_path='../data'
top_n = 40
cpv_column = 'codeCPV_2_3'

# %%
X = pd.read_csv(data_path, encoding='utf-8')

# %%
X = filter_top_cpv_categories(X, top_n=60, cpv_column=cpv_column)
# Split data first, before removing original anomalies
X_train, X_test = train_test_split(X,
                                   test_size=0.2,
                                   random_state=0,
                                   stratify=X[cpv_column],
                                   shuffle=True)
X_train, X_val = train_test_split(X_train,
                                  test_size=0.2,
                                  random_state=0,
                                  stratify=X_train[cpv_column],
                                  shuffle=True)
# Remove original anomalies from training and validation sets
#logger.info("Removing original anomalies from training and validation sets...")
anomaly_remover = OriginalAnomalyRemover()
anomaly_types = ['single_bid_competitive',
                'price_inflation',
                'price_deflation',
                #'procedure_manipulation',
                #'suspicious_modifications',
                'high_market_concentration',
                'temporal_clustering',
                #'excessive_subcontracting',
                #'short_contract_duration',
                'suspicious_buyer_supplier_pairs']
# Out:
# Filtered from 60 to 60 CPV categories, keeping 286412 rows out of 286412

# %%
# Clean training set
#logger.info("Cleaning training set...")
X_train = anomaly_remover.clean_dataset(
    X_train,
    anomaly_types=anomaly_types,
    strict_threshold=True
)

# Clean validation set
#logger.info("Cleaning validation set...")
X_val = anomaly_remover.clean_dataset(
    X_val,
    anomaly_types=anomaly_types,
    strict_threshold=True
)
# Out:
# INFO:scripts.synthetic_anomaly_generator:Identifying original anomalies for removal...
# INFO:scripts.synthetic_anomaly_generator:Checking for: single_bid_competitive, price_inflation, price_deflation, high_market_concentration, temporal_clustering, suspicious_buyer_supplier_pairs
# INFO:scripts.synthetic_anomaly_generator:single_bid_competitive: found 8595 anomalies
# INFO:scripts.synthetic_anomaly_generator:price_inflation: found 3050 anomalies
# INFO:scripts.synthetic_anomaly_generator:price_deflation: found 0 anomalies
# INFO:scripts.synthetic_anomaly_generator:high_market_concentration: found 2300 anomalies
# INFO:scripts.synthetic_anomaly_generator:temporal_clustering: found 3711 anomalies
# INFO:scripts.synthetic_anomaly_generator:suspicious_buyer_supplier_pairs: found 6197 anomalies
# INFO:scripts.synthetic_anomaly_generator:Total unique anomalous rows identified: 20161 (11.00%)
# INFO:scripts.synthetic_anomaly_generator:Removed 20161 anomalous rows (11.00%)
# INFO:scripts.synthetic_anomaly_generator:Clean dataset: 163142 rows (was 183303 rows)
# INFO:scripts.synthetic_anomaly_generator:Identifying original anomalies for removal...
# INFO:scripts.synthetic_anomaly_generator:Checking for: single_bid_competitive, price_inflation, price_deflation, high_market_concentration, temporal_clustering, suspicious_buyer_supplier_pairs
# INFO:scripts.synthetic_anomaly_generator:single_bid_competitive: found 2103 anomalies
# INFO:scripts.synthetic_anomaly_generator:price_inflation: found 673 anomalies
# INFO:scripts.synthetic_anomaly_generator:price_deflation: found 0 anomalies
# INFO:scripts.synthetic_anomaly_generator:high_market_concentration: found 241 anomalies
# INFO:scripts.synthetic_anomaly_generator:temporal_clustering: found 201 anomalies
# INFO:scripts.synthetic_anomaly_generator:suspicious_buyer_supplier_pairs: found 683 anomalies
# INFO:scripts.synthetic_anomaly_generator:Total unique anomalous rows identified: 3570 (7.79%)
# INFO:scripts.synthetic_anomaly_generator:Removed 3570 anomalous rows (7.79%)
# INFO:scripts.synthetic_anomaly_generator:Clean dataset: 42256 rows (was 45826 rows)

# %%
# Preprocess pipeline
numerical_columns = ['montant', 'dureeMois', 'offresRecues']
binary_columns = ['sousTraitanceDeclaree', 'origineFrance',
                  'marcheInnovant', 'idAccordCadre']

categorical_columns = ['procedure', 'nature', 'formePrix', 'ccag',
                       'typeGroupementOperateurs', 'tauxAvance_cat',
                       cpv_column]

nodes_columns = ['acheteur_id', 'titulaire_id']

preproc_pipeline = create_pipeline(numerical_columns,
                                   binary_columns,
                                 categorical_columns)
X_train_preproc = preproc_pipeline.fit_transform(X_train)
X_train_preproc.index = X_train.index
X_train_preproc = pd.concat([X_train_preproc, X_train[nodes_columns]],
                           axis=1)
X_val_preproc = preproc_pipeline.transform(X_val)
X_val_preproc.index = X_val.index
X_val_preproc = pd.concat([X_val_preproc, X_val[nodes_columns]],
                         axis=1)
# Out:
# /Users/loicdogon/.pyenv/versions/3.10.6/envs/decp_ml_env/lib/python3.10/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
# Generate synthetic anomalies for test set
#logger.info("Generating synthetic anomalies for test set...")
generator = SyntheticAnomalyGenerator(random_seed=42)
X_test_copy = X_test.copy()
# Reset index to avoid index mismatch issues
X_test_copy = X_test_copy.reset_index(drop=True)
# Generate anomalies
X_test_anomalies = generator.generate_anomalies(
    X_test_copy,
    anomaly_percentage=0.10,  # 10% anomalies
    anomaly_types=anomaly_types
)
X_test_preproc = preproc_pipeline.transform(X_test_anomalies)
X_test_preproc.index = X_test_anomalies.index
X_test_preproc = pd.concat([X_test_preproc,
                           X_test_anomalies[nodes_columns]], axis=1)
# Out:
# INFO:scripts.synthetic_anomaly_generator:Generating 5728 total synthetic anomaly rows by replacing
# INFO:scripts.synthetic_anomaly_generator:Approximately 954 anomalies per type
# INFO:scripts.synthetic_anomaly_generator:Generating single_bid_competitive anomalies...
# INFO:scripts.synthetic_anomaly_generator:Generated 954 single bid competitive anomaly rows
# INFO:scripts.synthetic_anomaly_generator:Generating price_inflation anomalies...
# INFO:scripts.synthetic_anomaly_generator:Generated 954 price inflation anomaly rows
# INFO:scripts.synthetic_anomaly_generator:Generating price_deflation anomalies...
# INFO:scripts.synthetic_anomaly_generator:Generated 954 price deflation anomaly rows
# INFO:scripts.synthetic_anomaly_generator:Generating high_market_concentration anomalies...
# INFO:scripts.synthetic_anomaly_generator:Generated 954 high market concentration anomaly rows
# INFO:scripts.synthetic_anomaly_generator:Generating temporal_clustering anomalies...
# INFO:scripts.synthetic_anomaly_generator:Generated 952 temporal clustering anomaly rows
# INFO:scripts.synthetic_anomaly_generator:Generating suspicious_buyer_supplier_pairs anomalies...
# INFO:scripts.synthetic_anomaly_generator:Generated 954 suspicious buyer-supplier pair anomaly rows (target threshold: 8,448,544)
# INFO:scripts.synthetic_anomaly_generator:Generated 5071 total synthetic anomaly rows
# INFO:scripts.synthetic_anomaly_generator:Original dataset: 57283 rows
# INFO:scripts.synthetic_anomaly_generator:Final dataset: 57283 rows
# INFO:scripts.synthetic_anomaly_generator:Replaced 5071 original rows
# INFO:scripts.synthetic_anomaly_generator:Anomaly type mapping:
# INFO:scripts.synthetic_anomaly_generator:  - 1: single_bid_competitive (878 anomalies)
# INFO:scripts.synthetic_anomaly_generator:  - 2: price_inflation (897 anomalies)
# INFO:scripts.synthetic_anomaly_generator:  - 3: price_deflation (919 anomalies)
# INFO:scripts.synthetic_anomaly_generator:  - 4: high_market_concentration (935 anomalies)
# INFO:scripts.synthetic_anomaly_generator:  - 5: temporal_clustering (488 anomalies)
# INFO:scripts.synthetic_anomaly_generator:  - 6: suspicious_buyer_supplier_pairs (954 anomalies)
# /Users/loicdogon/.pyenv/versions/3.10.6/envs/decp_ml_env/lib/python3.10/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
X_train_preproc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 163142 entries, 115161 to 179392
# Data columns (total 96 columns):
#  #   Column                                                                                Non-Null Count   Dtype
# ---  ------                                                                                --------------   -----
#  0   offres_recues_pipeline__offresRecues                                                  163142 non-null  float64
#  1   other_num_pipeline__montant                                                           163142 non-null  float64
#  2   other_num_pipeline__dureeMois                                                         163142 non-null  float64
#  3   binary_pipeline__sousTraitanceDeclaree                                                163142 non-null  float64
#  4   binary_pipeline__origineFrance                                                        163142 non-null  float64
#  5   binary_pipeline__marcheInnovant                                                       163142 non-null  float64
#  6   binary_pipeline__idAccordCadre                                                        163142 non-null  float64
#  7   cat_pipeline__procedure_Appel d'offres ouvert                                         163142 non-null  float64
#  8   cat_pipeline__procedure_Appel d'offres restreint                                      163142 non-null  float64
#  9   cat_pipeline__procedure_Dialogue compétitif                                           163142 non-null  float64
#  10  cat_pipeline__procedure_Marché passé sans publicité ni mise en concurrence préalable  163142 non-null  float64
#  11  cat_pipeline__procedure_Procédure adaptée                                             163142 non-null  float64
#  12  cat_pipeline__procedure_Procédure avec négociation                                    163142 non-null  float64
#  13  cat_pipeline__nature_Marché                                                           163142 non-null  float64
#  14  cat_pipeline__nature_Marché de défense ou de sécurité                                 163142 non-null  float64
#  15  cat_pipeline__nature_Marché de partenariat                                            163142 non-null  float64
#  16  cat_pipeline__formePrix_Forfaitaire                                                   163142 non-null  float64
#  17  cat_pipeline__formePrix_Mixte                                                         163142 non-null  float64
#  18  cat_pipeline__formePrix_Unitaire                                                      163142 non-null  float64
#  19  cat_pipeline__ccag_Fournitures courantes et services                                  163142 non-null  float64
#  20  cat_pipeline__ccag_Maitrise d'œuvre                                                   163142 non-null  float64
#  21  cat_pipeline__ccag_Marchés industriels                                                163142 non-null  float64
#  22  cat_pipeline__ccag_Pas de CCAG                                                        163142 non-null  float64
#  23  cat_pipeline__ccag_Prestations intellectuelles                                        163142 non-null  float64
#  24  cat_pipeline__ccag_Techniques de l'information et de la communication                 163142 non-null  float64
#  25  cat_pipeline__ccag_Travaux                                                            163142 non-null  float64
#  26  cat_pipeline__typeGroupementOperateurs_Conjoint                                       163142 non-null  float64
#  27  cat_pipeline__typeGroupementOperateurs_Pas de groupement                              163142 non-null  float64
#  28  cat_pipeline__typeGroupementOperateurs_Solidaire                                      163142 non-null  float64
#  29  cat_pipeline__tauxAvance_cat_large_advance                                            163142 non-null  float64
#  30  cat_pipeline__tauxAvance_cat_medium_advance                                           163142 non-null  float64
#  31  cat_pipeline__tauxAvance_cat_missing                                                  163142 non-null  float64
#  32  cat_pipeline__tauxAvance_cat_no_advance                                               163142 non-null  float64
#  33  cat_pipeline__tauxAvance_cat_small_advance                                            163142 non-null  float64
#  34  cat_pipeline__codeCPV_2_3_0                                                           163142 non-null  float64
#  35  cat_pipeline__codeCPV_2_3_14000000                                                    163142 non-null  float64
#  36  cat_pipeline__codeCPV_2_3_15000000                                                    163142 non-null  float64
#  37  cat_pipeline__codeCPV_2_3_16000000                                                    163142 non-null  float64
#  38  cat_pipeline__codeCPV_2_3_18000000                                                    163142 non-null  float64
#  39  cat_pipeline__codeCPV_2_3_19000000                                                    163142 non-null  float64
#  40  cat_pipeline__codeCPV_2_3_22000000                                                    163142 non-null  float64
#  41  cat_pipeline__codeCPV_2_3_24000000                                                    163142 non-null  float64
#  42  cat_pipeline__codeCPV_2_3_28000000                                                    163142 non-null  float64
#  43  cat_pipeline__codeCPV_2_3_29000000                                                    163142 non-null  float64
#  44  cat_pipeline__codeCPV_2_3_3000000                                                     163142 non-null  float64
#  45  cat_pipeline__codeCPV_2_3_30000000                                                    163142 non-null  float64
#  46  cat_pipeline__codeCPV_2_3_31000000                                                    163142 non-null  float64
#  47  cat_pipeline__codeCPV_2_3_32000000                                                    163142 non-null  float64
#  48  cat_pipeline__codeCPV_2_3_33000000                                                    163142 non-null  float64
#  49  cat_pipeline__codeCPV_2_3_34000000                                                    163142 non-null  float64
#  50  cat_pipeline__codeCPV_2_3_35000000                                                    163142 non-null  float64
#  51  cat_pipeline__codeCPV_2_3_37000000                                                    163142 non-null  float64
#  52  cat_pipeline__codeCPV_2_3_38000000                                                    163142 non-null  float64
#  53  cat_pipeline__codeCPV_2_3_39000000                                                    163142 non-null  float64
#  54  cat_pipeline__codeCPV_2_3_40000000                                                    163142 non-null  float64
#  55  cat_pipeline__codeCPV_2_3_41000000                                                    163142 non-null  float64
#  56  cat_pipeline__codeCPV_2_3_42000000                                                    163142 non-null  float64
#  57  cat_pipeline__codeCPV_2_3_43000000                                                    163142 non-null  float64
#  58  cat_pipeline__codeCPV_2_3_44000000                                                    163142 non-null  float64
#  59  cat_pipeline__codeCPV_2_3_45000000                                                    163142 non-null  float64
#  60  cat_pipeline__codeCPV_2_3_45100000                                                    163142 non-null  float64
#  61  cat_pipeline__codeCPV_2_3_45200000                                                    163142 non-null  float64
#  62  cat_pipeline__codeCPV_2_3_45300000                                                    163142 non-null  float64
#  63  cat_pipeline__codeCPV_2_3_45400000                                                    163142 non-null  float64
#  64  cat_pipeline__codeCPV_2_3_45500000                                                    163142 non-null  float64
#  65  cat_pipeline__codeCPV_2_3_48000000                                                    163142 non-null  float64
#  66  cat_pipeline__codeCPV_2_3_50000000                                                    163142 non-null  float64
#  67  cat_pipeline__codeCPV_2_3_51000000                                                    163142 non-null  float64
#  68  cat_pipeline__codeCPV_2_3_55000000                                                    163142 non-null  float64
#  69  cat_pipeline__codeCPV_2_3_60000000                                                    163142 non-null  float64
#  70  cat_pipeline__codeCPV_2_3_63000000                                                    163142 non-null  float64
#  71  cat_pipeline__codeCPV_2_3_64000000                                                    163142 non-null  float64
#  72  cat_pipeline__codeCPV_2_3_65000000                                                    163142 non-null  float64
#  73  cat_pipeline__codeCPV_2_3_66000000                                                    163142 non-null  float64
#  74  cat_pipeline__codeCPV_2_3_70000000                                                    163142 non-null  float64
#  75  cat_pipeline__codeCPV_2_3_71000000                                                    163142 non-null  float64
#  76  cat_pipeline__codeCPV_2_3_71200000                                                    163142 non-null  float64
#  77  cat_pipeline__codeCPV_2_3_71300000                                                    163142 non-null  float64
#  78  cat_pipeline__codeCPV_2_3_71400000                                                    163142 non-null  float64
#  79  cat_pipeline__codeCPV_2_3_71500000                                                    163142 non-null  float64
#  80  cat_pipeline__codeCPV_2_3_71600000                                                    163142 non-null  float64
#  81  cat_pipeline__codeCPV_2_3_71700000                                                    163142 non-null  float64
#  82  cat_pipeline__codeCPV_2_3_72000000                                                    163142 non-null  float64
#  83  cat_pipeline__codeCPV_2_3_73000000                                                    163142 non-null  float64
#  84  cat_pipeline__codeCPV_2_3_74000000                                                    163142 non-null  float64
#  85  cat_pipeline__codeCPV_2_3_75000000                                                    163142 non-null  float64
#  86  cat_pipeline__codeCPV_2_3_77000000                                                    163142 non-null  float64
#  87  cat_pipeline__codeCPV_2_3_79000000                                                    163142 non-null  float64
#  88  cat_pipeline__codeCPV_2_3_80000000                                                    163142 non-null  float64
#  89  cat_pipeline__codeCPV_2_3_85000000                                                    163142 non-null  float64
#  90  cat_pipeline__codeCPV_2_3_9000000                                                     163142 non-null  float64
#  91  cat_pipeline__codeCPV_2_3_90000000                                                    163142 non-null  float64
#  92  cat_pipeline__codeCPV_2_3_92000000                                                    163142 non-null  float64
#  93  cat_pipeline__codeCPV_2_3_98000000                                                    163142 non-null  float64
#  94  acheteur_id                                                                           163142 non-null  int64
#  95  titulaire_id                                                                          163142 non-null  object
# dtypes: float64(94), int64(1), object(1)
# memory usage: 120.7+ MB

# %%
X_test_preproc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57283 entries, 0 to 57282
# Data columns (total 96 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   offres_recues_pipeline__offresRecues                                                  57283 non-null  float64
#  1   other_num_pipeline__montant                                                           57283 non-null  float64
#  2   other_num_pipeline__dureeMois                                                         57283 non-null  float64
#  3   binary_pipeline__sousTraitanceDeclaree                                                57283 non-null  float64
#  4   binary_pipeline__origineFrance                                                        57283 non-null  float64
#  5   binary_pipeline__marcheInnovant                                                       57283 non-null  float64
#  6   binary_pipeline__idAccordCadre                                                        57283 non-null  float64
#  7   cat_pipeline__procedure_Appel d'offres ouvert                                         57283 non-null  float64
#  8   cat_pipeline__procedure_Appel d'offres restreint                                      57283 non-null  float64
#  9   cat_pipeline__procedure_Dialogue compétitif                                           57283 non-null  float64
#  10  cat_pipeline__procedure_Marché passé sans publicité ni mise en concurrence préalable  57283 non-null  float64
#  11  cat_pipeline__procedure_Procédure adaptée                                             57283 non-null  float64
#  12  cat_pipeline__procedure_Procédure avec négociation                                    57283 non-null  float64
#  13  cat_pipeline__nature_Marché                                                           57283 non-null  float64
#  14  cat_pipeline__nature_Marché de défense ou de sécurité                                 57283 non-null  float64
#  15  cat_pipeline__nature_Marché de partenariat                                            57283 non-null  float64
#  16  cat_pipeline__formePrix_Forfaitaire                                                   57283 non-null  float64
#  17  cat_pipeline__formePrix_Mixte                                                         57283 non-null  float64
#  18  cat_pipeline__formePrix_Unitaire                                                      57283 non-null  float64
#  19  cat_pipeline__ccag_Fournitures courantes et services                                  57283 non-null  float64
#  20  cat_pipeline__ccag_Maitrise d'œuvre                                                   57283 non-null  float64
#  21  cat_pipeline__ccag_Marchés industriels                                                57283 non-null  float64
#  22  cat_pipeline__ccag_Pas de CCAG                                                        57283 non-null  float64
#  23  cat_pipeline__ccag_Prestations intellectuelles                                        57283 non-null  float64
#  24  cat_pipeline__ccag_Techniques de l'information et de la communication                 57283 non-null  float64
#  25  cat_pipeline__ccag_Travaux                                                            57283 non-null  float64
#  26  cat_pipeline__typeGroupementOperateurs_Conjoint                                       57283 non-null  float64
#  27  cat_pipeline__typeGroupementOperateurs_Pas de groupement                              57283 non-null  float64
#  28  cat_pipeline__typeGroupementOperateurs_Solidaire                                      57283 non-null  float64
#  29  cat_pipeline__tauxAvance_cat_large_advance                                            57283 non-null  float64
#  30  cat_pipeline__tauxAvance_cat_medium_advance                                           57283 non-null  float64
#  31  cat_pipeline__tauxAvance_cat_missing                                                  57283 non-null  float64
#  32  cat_pipeline__tauxAvance_cat_no_advance                                               57283 non-null  float64
#  33  cat_pipeline__tauxAvance_cat_small_advance                                            57283 non-null  float64
#  34  cat_pipeline__codeCPV_2_3_0                                                           57283 non-null  float64
#  35  cat_pipeline__codeCPV_2_3_14000000                                                    57283 non-null  float64
#  36  cat_pipeline__codeCPV_2_3_15000000                                                    57283 non-null  float64
#  37  cat_pipeline__codeCPV_2_3_16000000                                                    57283 non-null  float64
#  38  cat_pipeline__codeCPV_2_3_18000000                                                    57283 non-null  float64
#  39  cat_pipeline__codeCPV_2_3_19000000                                                    57283 non-null  float64
#  40  cat_pipeline__codeCPV_2_3_22000000                                                    57283 non-null  float64
#  41  cat_pipeline__codeCPV_2_3_24000000                                                    57283 non-null  float64
#  42  cat_pipeline__codeCPV_2_3_28000000                                                    57283 non-null  float64
#  43  cat_pipeline__codeCPV_2_3_29000000                                                    57283 non-null  float64
#  44  cat_pipeline__codeCPV_2_3_3000000                                                     57283 non-null  float64
#  45  cat_pipeline__codeCPV_2_3_30000000                                                    57283 non-null  float64
#  46  cat_pipeline__codeCPV_2_3_31000000                                                    57283 non-null  float64
#  47  cat_pipeline__codeCPV_2_3_32000000                                                    57283 non-null  float64
#  48  cat_pipeline__codeCPV_2_3_33000000                                                    57283 non-null  float64
#  49  cat_pipeline__codeCPV_2_3_34000000                                                    57283 non-null  float64
#  50  cat_pipeline__codeCPV_2_3_35000000                                                    57283 non-null  float64
#  51  cat_pipeline__codeCPV_2_3_37000000                                                    57283 non-null  float64
#  52  cat_pipeline__codeCPV_2_3_38000000                                                    57283 non-null  float64
#  53  cat_pipeline__codeCPV_2_3_39000000                                                    57283 non-null  float64
#  54  cat_pipeline__codeCPV_2_3_40000000                                                    57283 non-null  float64
#  55  cat_pipeline__codeCPV_2_3_41000000                                                    57283 non-null  float64
#  56  cat_pipeline__codeCPV_2_3_42000000                                                    57283 non-null  float64
#  57  cat_pipeline__codeCPV_2_3_43000000                                                    57283 non-null  float64
#  58  cat_pipeline__codeCPV_2_3_44000000                                                    57283 non-null  float64
#  59  cat_pipeline__codeCPV_2_3_45000000                                                    57283 non-null  float64
#  60  cat_pipeline__codeCPV_2_3_45100000                                                    57283 non-null  float64
#  61  cat_pipeline__codeCPV_2_3_45200000                                                    57283 non-null  float64
#  62  cat_pipeline__codeCPV_2_3_45300000                                                    57283 non-null  float64
#  63  cat_pipeline__codeCPV_2_3_45400000                                                    57283 non-null  float64
#  64  cat_pipeline__codeCPV_2_3_45500000                                                    57283 non-null  float64
#  65  cat_pipeline__codeCPV_2_3_48000000                                                    57283 non-null  float64
#  66  cat_pipeline__codeCPV_2_3_50000000                                                    57283 non-null  float64
#  67  cat_pipeline__codeCPV_2_3_51000000                                                    57283 non-null  float64
#  68  cat_pipeline__codeCPV_2_3_55000000                                                    57283 non-null  float64
#  69  cat_pipeline__codeCPV_2_3_60000000                                                    57283 non-null  float64
#  70  cat_pipeline__codeCPV_2_3_63000000                                                    57283 non-null  float64
#  71  cat_pipeline__codeCPV_2_3_64000000                                                    57283 non-null  float64
#  72  cat_pipeline__codeCPV_2_3_65000000                                                    57283 non-null  float64
#  73  cat_pipeline__codeCPV_2_3_66000000                                                    57283 non-null  float64
#  74  cat_pipeline__codeCPV_2_3_70000000                                                    57283 non-null  float64
#  75  cat_pipeline__codeCPV_2_3_71000000                                                    57283 non-null  float64
#  76  cat_pipeline__codeCPV_2_3_71200000                                                    57283 non-null  float64
#  77  cat_pipeline__codeCPV_2_3_71300000                                                    57283 non-null  float64
#  78  cat_pipeline__codeCPV_2_3_71400000                                                    57283 non-null  float64
#  79  cat_pipeline__codeCPV_2_3_71500000                                                    57283 non-null  float64
#  80  cat_pipeline__codeCPV_2_3_71600000                                                    57283 non-null  float64
#  81  cat_pipeline__codeCPV_2_3_71700000                                                    57283 non-null  float64
#  82  cat_pipeline__codeCPV_2_3_72000000                                                    57283 non-null  float64
#  83  cat_pipeline__codeCPV_2_3_73000000                                                    57283 non-null  float64
#  84  cat_pipeline__codeCPV_2_3_74000000                                                    57283 non-null  float64
#  85  cat_pipeline__codeCPV_2_3_75000000                                                    57283 non-null  float64
#  86  cat_pipeline__codeCPV_2_3_77000000                                                    57283 non-null  float64
#  87  cat_pipeline__codeCPV_2_3_79000000                                                    57283 non-null  float64
#  88  cat_pipeline__codeCPV_2_3_80000000                                                    57283 non-null  float64
#  89  cat_pipeline__codeCPV_2_3_85000000                                                    57283 non-null  float64
#  90  cat_pipeline__codeCPV_2_3_9000000                                                     57283 non-null  float64
#  91  cat_pipeline__codeCPV_2_3_90000000                                                    57283 non-null  float64
#  92  cat_pipeline__codeCPV_2_3_92000000                                                    57283 non-null  float64
#  93  cat_pipeline__codeCPV_2_3_98000000                                                    57283 non-null  float64
#  94  acheteur_id                                                                           57283 non-null  int64
#  95  titulaire_id                                                                          57283 non-null  object
# dtypes: float64(94), int64(1), object(1)
# memory usage: 42.0+ MB
