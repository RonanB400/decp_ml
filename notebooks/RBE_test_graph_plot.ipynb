# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sqlite3
import sys
import logging
import pickle
import logging

from scripts.graph_plot_builder import GraphPlotBuilder

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATA_PATH = os.path.join(os.path.dirname(os.getcwd()),
                        'data')

graph_builder = GraphPlotBuilder()

df = graph_builder.load_data(DATA_PATH)

graph_builder.create_graph(df)
# Out:
# INFO:scripts.graph_plot_builder:Loading data from /home/ronan/code/RonanB400/Project/decp_ml/data
# /home/ronan/code/RonanB400/Project/decp_ml/scripts/graph_plot_builder.py:35: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   X = pd.read_csv(data_file_path, encoding='utf-8')
# INFO:scripts.graph_plot_builder:Creating graph structure from procurement data...
# INFO:scripts.graph_plot_builder:Filtered contracts with amount >= 20,000.00€
# INFO:scripts.graph_plot_builder:Filtered to 279473 valid contracts (removed 7377 contracts with missing names)
# INFO:scripts.graph_plot_builder:Creating edges from procurement data...
# INFO:scripts.graph_plot_builder:Computing node features with vectorized operations...
# {'nodes': ['COMMUNE DE SAINT ETIENNE DE TINEE',
#   'COMMUNE DE CHALMOUX',
#   "CC DES PORTES D'ARIEGE PYRENEES",
#   'TOULOUSE METROPOLE',
#   'COMMUNE DE SAINT SAULVE',
#   'COMMUNE DE PIERRELATTE',
# ...

# %%
with open(os.path.join(DATA_PATH, 'graph_data_clean.pkl'), 'rb') as f:
    graph_data = pickle.load(f)

graph_data.keys()
# Out:
# dict_keys(['nodes', 'edges', 'node_features', 'edge_features', 'node_types', 'buyer_to_id', 'supplier_to_id', 'contract_ids', 'contract_data'])

# %%
graph_builder.plot_graph_graphistry(graph_data, max_nodes=500, max_edges=10_000)
# Out:
# INFO:scripts.graph_plot_builder:Creating Graphistry visualization...
# INFO:scripts.graph_plot_builder:Limiting display to 500 nodes (total: 67024)
# INFO:scripts.graph_plot_builder:Limiting edges to 10000 (total: 14864)
# ERROR:scripts.graph_plot_builder:Failed to create Graphistry visualization: Must call login() first

# %%
graph_path = os.path.join(DATA_PATH, 'graph_visualization.html')
graph_builder.plot_graph(graph_data, output_path=graph_path, max_nodes=500, max_edges=10_000)
# Out:
# INFO:scripts.graph_plot_builder:Creating graph visualization with pyvis...
# INFO:scripts.graph_plot_builder:Limiting display to 500 nodes (total: 67024)
# INFO:scripts.graph_plot_builder:Limiting edges to 10000 (total: 14864)
# INFO:scripts.graph_plot_builder:Using 10000 edges after filtering
# INFO:scripts.graph_plot_builder:Computing initial node positions...
# INFO:scripts.graph_plot_builder:Graph visualization saved to /home/ronan/code/RonanB400/Project/decp_ml/data/graph_visualization.html
# INFO:scripts.graph_plot_builder:Visualization created with 500 nodes and 10000 edges
